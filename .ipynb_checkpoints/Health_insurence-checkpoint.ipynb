# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Health_Insurence.csv')

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# ...

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
# drop the  missing columns
df.dropna(subset=['age','bmi'],inplace=True)

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# dtype: int64

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
# Encoding categorical variables
categorical_cols = ['sex', 'hereditary_diseases', 'city', 'job_title']
numerical_cols = ['age', 'weight', 'bmi', 'no_of_dependents', 'smoker', 'bloodpressure', 'diabetes', 'regular_ex']

# %%
categorical_cols
# Out:
# ['sex', 'hereditary_diseases', 'city', 'job_title']

# %%
from sklearn.compose import ColumnTransformer

# %%
preprocessor=ColumnTransformer([ ('num', StandardScaler(), numerical_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['age', 'weight', 'bmi', 'no_of_dependents',
#                                   'smoker', 'bloodpressure', 'diabetes',
#                                   'regular_ex']),
#                                 ('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['sex', 'hereditary_diseases', 'city',
#                                   'job_title'])])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['claim'], bins=30, kde=True)
plt.title("Distribution of Insurance Claims")
plt.xlabel("Claim Amount")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['smoker'], y=df['claim'])
plt.title("Impact of Smoking on Claim Amount")
plt.xlabel("Smoker (0=No, 1=Yes)")
plt.ylabel("Claim Amount")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df['bmi'], y=df['claim'], hue=df['diabetes'])
plt.title("BMI vs Claim Amount (Colored by Diabetes Status)")
plt.xlabel("BMI")
plt.ylabel("Claim Amount")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['sex'], y=df['claim'])
plt.title("Impact of Gender on Claim Amount")
plt.xlabel("Gender")
plt.ylabel("Claim Amount")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Identify categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Apply Label Encoding
le = LabelEncoder()
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# Now compute correlation
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap of Features")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x=df['diabetes'], y=df['claim'], hue=df['sex'], split=True)
plt.title("Claim Amount Distribution by Diabetes and Gender")
plt.xlabel("Diabetes (0=No, 1=Yes)")
plt.ylabel("Claim Amount")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['claim'])
y=df['claim']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker  \
# 6138   19.0    0      47  28.3                    8                 0       1
# 3195   23.0    1      62  34.4                    8                 0       0
# 581    52.0    0      71  25.3                    8                 2       1
# 10665  24.0    0      51  26.6                    8                 0       0
# 6698   33.0    1      74  22.7                    8                 0       0
# ...     ...  ...     ...   ...                  ...               ...     ...
# 5696   59.0    1      64  29.8                    8                 3       1
# 14746  18.0    1      50  28.5                    8                 0       0
# 5920   22.0    0      43  29.4                    1                 3       1
# 952    42.0    1      54  34.1                    8                 0       0
# 8001   28.0    0      87  24.3                    8                 1       0
#
# ...

# %%
x_test
# Out:
#         age  sex  weight   bmi  hereditary_diseases  no_of_dependents  smoker  \
# 3076   19.0    0      60  28.9                    8                 0       0
# 5787   35.0    0      84  38.1                    8                 2       0
# 6668   64.0    0      64  39.1                    8                 3       0
# 1873   45.0    0      83  26.3                    8                 1       1
# 14396  37.0    1      46  24.3                    8                 2       0
# ...     ...  ...     ...   ...                  ...               ...     ...
# 13962  59.0    0      75  27.8                    8                 3       0
# 13410  19.0    1      65  27.8                    8                 0       0
# 278    55.0    0      50  33.5                    8                 2       0
# 482    27.0    1      50  34.6                    5                 0       1
# 9220   30.0    0      53  27.9                    8                 0       0
#
# ...

# %%
y_train
# Out:
# 6138     17469.0
# 3195      1826.8
# 581      24667.4
# 10665     3046.1
# 6698     21984.5
#           ...
# 5696     30184.9
# 14746     1712.2
# 5920     35595.6
# 952       5979.7
# 8001     23288.9
# Name: claim, Length: 10918, dtype: float64

# %%
y_test
# Out:
# 3076      1743.2
# 5787     24915.1
# 6668     16085.1
# 1873     17921.6
# 14396     6198.8
#           ...
# 13962    14001.3
# 13410     1635.7
# 278      12269.7
# 482      39611.8
# 9220      4137.5
# Name: claim, Length: 2730, dtype: float64

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# %%
model=Pipeline([
    ('preprocessor',preprocessor),
    ('regrssor',RandomForestRegressor(n_estimators=100,random_state=42))])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'weight', 'bmi',
#                                                    'no_of_dependents', 'smoker',
#                                                    'bloodpressure', 'diabetes',
#                                                    'regular_ex']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['sex', 'hereditary_diseases',
#                                                    'city', 'job_title'])])),
#                 ('regrssor', RandomForestRegressor(random_state=42))])

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 1743.2, 24915.1, 16085.1, ..., 12269.7, 39611.8,  4137.5])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 522.5859611721696

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 5048909.592100986

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9657106399816117

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',LinearRegression())
])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'weight', 'bmi',
#                                                    'no_of_dependents', 'smoker',
#                                                    'bloodpressure', 'diabetes',
#                                                    'regular_ex']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['sex', 'hereditary_diseases',
#                                                    'city', 'job_title'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 3948.19097142,  9569.29683583, 18161.37969407, ...,
#        16175.31552409, 38041.45680101,  3353.20456269])

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 3640.038943223982

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 31577918.522050582

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.7855405019475996

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=Pipeline([
    ('preprocessor',preprocessor),
    ('regressor',DecisionTreeRegressor(criterion='squared_error',random_state=42))
])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'weight', 'bmi',
#                                                    'no_of_dependents', 'smoker',
#                                                    'bloodpressure', 'diabetes',
#                                                    'regular_ex']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['sex', 'hereditary_diseases',
#                                                    'city', 'job_title'])])),
#                 ('regressor', DecisionTreeRegressor(random_state=42))])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 1743.2, 24915.1, 16085.1, ..., 12269.7, 39611.8,  4137.5])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 543.7323076923088

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 8055698.6252014665

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9452902165664993

# %%
sample_input = x_test.iloc[:5]  # Selecting first 5 test samples
y_sample_pred = model.predict(sample_input)

print("\nDemo Test Predictions:")
for i, pred in enumerate(y_sample_pred):
    print(f"Sample {i+1}: Predicted Claim Amount = {pred}")
# Out:
# Demo Test Predictions:
# Sample 1: Predicted Claim Amount = 1743.2000000000005
# Sample 2: Predicted Claim Amount = 24915.1
# Sample 3: Predicted Claim Amount = 16085.100000000002
# Sample 4: Predicted Claim Amount = 22478.600000000002
# Sample 5: Predicted Claim Amount = 6198.800000000001
